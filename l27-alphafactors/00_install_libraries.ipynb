# %% [markdown]
# ## Install libraries
#
# It takes some time to install the python libraries for the first time, but this only needs to be done once for all the coding exercises in this lesson.  Please run this code in a separate tab while you continue watching the videos.  Once you get to the first coding exercise of the lesson, if this notebook is done installing, then you won't have to wait for the installation to start running the code in that exercise.

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Collecting alphalens==0.3.2
#   Downloading alphalens-0.3.2.tar.gz (18.9 MB)
#      |████████████████████████████████| 18.9 MB 235 kB/s  eta 0:00:01   |██████▎                         | 3.7 MB 3.5 MB/s eta 0:00:05     |███████▏                        | 4.2 MB 3.5 MB/s eta 0:00:05     |██████████████████████████      | 15.4 MB 13.5 MB/s eta 0:00:01
# Collecting colour==0.1.5
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Collecting cvxpy==1.0.3
#   Downloading cvxpy-1.0.3.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 7.8 MB/s eta 0:00:01
# Requirement already satisfied: cycler==0.10.0 in /anaconda3/lib/python3.6/site-packages (from -r requirements.txt (line 4)) (0.10.0)
# Collecting numpy==1.14.5
#   Using cached numpy-1.14.5-cp36-cp36m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (4.7 MB)
# Processing /Users/anirudh/Library/Caches/pip/wheels/32/15/fe/873be370134a62a116784ac2e08df00bad7ef4bec708e1f73c/pandas-0.18.1-cp36-cp36m-macosx_10_9_x86_64.whl
# Requirement already satisfied: plotly==2.2.3 in /anaconda3/lib/python3.6/site-packages (from -r requirements.txt (line 7)) (2.2.3)
# Collecting pyparsing==2.2.0
#   Downloading pyparsing-2.2.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 7.4 MB/s  eta 0:00:01
# Collecting python-dateutil==2.6.1
#   Downloading python_dateutil-2.6.1-py2.py3-none-any.whl (194 kB)
#      |████████████████████████████████| 194 kB 13.7 MB/s eta 0:00:01
# Collecting pytz==2017.3
#   Downloading pytz-2017.3-py2.py3-none-any.whl (511 kB)
#      |████████████████████████████████| 511 kB 12.2 MB/s eta 0:00:01
# Collecting requests==2.18.4
#   Downloading requests-2.18.4-py2.py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 2.8 MB/s eta 0:00:01
# Collecting scipy==1.0.0
#   Downloading scipy-1.0.0-cp36-cp36m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (16.7 MB)
#      |████████████████████████████████| 16.7 MB 15.0 MB/s eta 0:00:01     |█████████████████████████       | 13.1 MB 15.0 MB/s eta 0:00:01
# Requirement already satisfied: scikit-learn==0.19.1 in /anaconda3/lib/python3.6/site-packages (from -r requirements.txt (line 13)) (0.19.1)
# Requirement already satisfied: six==1.11.0 in /anaconda3/lib/python3.6/site-packages (from -r requirements.txt (line 14)) (1.11.0)
# Collecting tqdm==4.19.5
#   Downloading tqdm-4.19.5-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 398 kB/s  eta 0:00:01
# Processing /Users/anirudh/Library/Caches/pip/wheels/05/13/88/164e4ac4e2662016300b12a0ab0920780bbb725120ccdb858a/zipline-1.2.0-cp36-cp36m-macosx_10_9_x86_64.whl
# Collecting graphviz==0.9
#   Using cached graphviz-0.9-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: matplotlib>=1.4.0 in /anaconda3/lib/python3.6/site-packages (from alphalens==0.3.2->-r requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: seaborn>=0.6.0 in /anaconda3/lib/python3.6/site-packages (from alphalens==0.3.2->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: statsmodels>=0.6.1 in /anaconda3/lib/python3.6/site-packages (from alphalens==0.3.2->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: IPython>=3.2.3 in /anaconda3/lib/python3.6/site-packages (from alphalens==0.3.2->-r requirements.txt (line 1)) (7.8.0)
# Collecting osqp
#   Downloading osqp-0.6.1-cp36-cp36m-macosx_10_7_x86_64.whl (161 kB)
#      |████████████████████████████████| 161 kB 10.7 MB/s eta 0:00:01
# Collecting ecos>=2
#   Downloading ecos-2.0.7.post1-cp36-cp36m-macosx_10_13_x86_64.whl (71 kB)
#      |████████████████████████████████| 71 kB 26 kB/s s eta 0:00:01
# Collecting scs>=1.1.3
#   Downloading scs-2.1.2.tar.gz (3.5 MB)
#      |████████████████████████████████| 3.5 MB 14.1 MB/s eta 0:00:01
# Collecting multiprocess
#   Downloading multiprocess-0.70.9.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 9.0 MB/s eta 0:00:01
# Requirement already satisfied: fastcache in /anaconda3/lib/python3.6/site-packages (from cvxpy==1.0.3->-r requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: toolz in /anaconda3/lib/python3.6/site-packages (from cvxpy==1.0.3->-r requirements.txt (line 3)) (0.10.0)
# Requirement already satisfied: nbformat>=4.2 in /anaconda3/lib/python3.6/site-packages (from plotly==2.2.3->-r requirements.txt (line 7)) (4.4.0)
# Requirement already satisfied: decorator>=4.0.6 in /anaconda3/lib/python3.6/site-packages (from plotly==2.2.3->-r requirements.txt (line 7)) (4.4.0)
# Collecting idna<2.7,>=2.5
#   Downloading idna-2.6-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.8 MB/s eta 0:00:01
# Collecting urllib3<1.23,>=1.21.1
#   Downloading urllib3-1.22-py2.py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 7.9 MB/s eta 0:00:01
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.6/site-packages (from requests==2.18.4->-r requirements.txt (line 11)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.6/site-packages (from requests==2.18.4->-r requirements.txt (line 11)) (2019.11.28)
# Requirement already satisfied: pip>=7.1.0 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (20.0.2)
# Requirement already satisfied: lru-dict>=1.1.4 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (1.1.6)
# Requirement already satisfied: tables>=3.3.0 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (3.5.2)
# Requirement already satisfied: alembic>=0.7.7 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (1.4.2)
# Requirement already satisfied: networkx<2.0,>=1.9.1 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (1.11)
# Requirement already satisfied: pandas-datareader<0.6,>=0.2.1 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (0.5.0)
# Requirement already satisfied: Cython>=0.25.2 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (0.29.8)
# Requirement already satisfied: empyrical>=0.4.2 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (0.5.3)
# Requirement already satisfied: sqlalchemy>=1.0.8 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (1.3.7)
# Requirement already satisfied: bottleneck>=1.0.0 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (1.2.1)
# Requirement already satisfied: intervaltree>=2.1.0 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (3.0.2)
# Requirement already satisfied: requests-file>=1.4.1 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (1.4.3)
# Requirement already satisfied: cyordereddict>=0.2.2 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (1.0.0)
# Requirement already satisfied: Mako>=1.0.1 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (1.1.2)
# Requirement already satisfied: click>=4.0.0 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (1.1.1)
# Requirement already satisfied: bcolz<1,>=0.12.1 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (0.12.1)
# Requirement already satisfied: patsy>=0.4.0 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (0.5.1)
# Requirement already satisfied: Logbook>=0.12.5 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (1.5.3)
# Requirement already satisfied: setuptools>18.0 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (41.0.1)
# Requirement already satisfied: contextlib2>=0.4.0 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (0.5.5)
# Requirement already satisfied: sortedcontainers>=1.4.4 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (2.1.0)
# Requirement already satisfied: numexpr>=2.6.1 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (2.7.0)
# Requirement already satisfied: multipledispatch>=0.4.8 in /anaconda3/lib/python3.6/site-packages (from zipline===1.2.0->-r requirements.txt (line 16)) (0.6.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /anaconda3/lib/python3.6/site-packages (from matplotlib>=1.4.0->alphalens==0.3.2->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: pickleshare in /anaconda3/lib/python3.6/site-packages (from IPython>=3.2.3->alphalens==0.3.2->-r requirements.txt (line 1)) (0.7.5)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /anaconda3/lib/python3.6/site-packages (from IPython>=3.2.3->alphalens==0.3.2->-r requirements.txt (line 1)) (0.1.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /anaconda3/lib/python3.6/site-packages (from IPython>=3.2.3->alphalens==0.3.2->-r requirements.txt (line 1)) (4.7.0)
# Requirement already satisfied: jedi>=0.10 in /anaconda3/lib/python3.6/site-packages (from IPython>=3.2.3->alphalens==0.3.2->-r requirements.txt (line 1)) (0.15.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /anaconda3/lib/python3.6/site-packages (from IPython>=3.2.3->alphalens==0.3.2->-r requirements.txt (line 1)) (2.0.9)
# Requirement already satisfied: backcall in /anaconda3/lib/python3.6/site-packages (from IPython>=3.2.3->alphalens==0.3.2->-r requirements.txt (line 1)) (0.1.0)
# Requirement already satisfied: traitlets>=4.2 in /anaconda3/lib/python3.6/site-packages (from IPython>=3.2.3->alphalens==0.3.2->-r requirements.txt (line 1)) (4.3.2)
# Requirement already satisfied: pygments in /anaconda3/lib/python3.6/site-packages (from IPython>=3.2.3->alphalens==0.3.2->-r requirements.txt (line 1)) (2.4.2)
# Requirement already satisfied: future in /anaconda3/lib/python3.6/site-packages (from osqp->cvxpy==1.0.3->-r requirements.txt (line 3)) (0.17.1)
# Collecting dill>=0.3.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      |████████████████████████████████| 151 kB 10.1 MB/s eta 0:00:01    |████▎                           | 20 kB 8.6 MB/s eta 0:00:01
# Requirement already satisfied: ipython_genutils in /anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 7)) (3.0.2)
# Requirement already satisfied: jupyter_core in /anaconda3/lib/python3.6/site-packages (from nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 7)) (4.5.0)
# Requirement already satisfied: mock>=2.0 in /anaconda3/lib/python3.6/site-packages (from tables>=3.3.0->zipline===1.2.0->-r requirements.txt (line 16)) (3.0.5)
# Requirement already satisfied: python-editor>=0.3 in /anaconda3/lib/python3.6/site-packages (from alembic>=0.7.7->zipline===1.2.0->-r requirements.txt (line 16)) (1.0.4)
# Requirement already satisfied: requests-ftp in /anaconda3/lib/python3.6/site-packages (from pandas-datareader<0.6,>=0.2.1->zipline===1.2.0->-r requirements.txt (line 16)) (0.3.1)
# Requirement already satisfied: ptyprocess>=0.5 in /anaconda3/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->IPython>=3.2.3->alphalens==0.3.2->-r requirements.txt (line 1)) (0.6.0)
# Requirement already satisfied: parso>=0.5.0 in /anaconda3/lib/python3.6/site-packages (from jedi>=0.10->IPython>=3.2.3->alphalens==0.3.2->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: wcwidth in /anaconda3/lib/python3.6/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython>=3.2.3->alphalens==0.3.2->-r requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: pyrsistent>=0.14.0 in /anaconda3/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 7)) (0.14.11)
# Requirement already satisfied: attrs>=17.4.0 in /anaconda3/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 7)) (19.1.0)
# Building wheels for collected packages: alphalens, cvxpy, scs, multiprocess, dill
#   Building wheel for alphalens (setup.py) ... done
#   Created wheel for alphalens: filename=alphalens-0.3.2-py3-none-any.whl size=18881511 sha256=37d0dc67a6ed30f22c20ae2e35791dd2c950b2fb76477dcee9b3327116cdde54
#   Stored in directory: /Users/anirudh/Library/Caches/pip/wheels/1c/9e/b8/a502db514b9cf748687129d96fb1f8156f47ef6ab450abf4d0
#   Building wheel for cvxpy (setup.py) ... done
#   Created wheel for cvxpy: filename=cvxpy-1.0.3-cp36-cp36m-macosx_10_9_x86_64.whl size=627769 sha256=92d5920334de733fd9381e26e3f4b1f25482730c93b3e5fa0f33c6462b6ea995
#   Stored in directory: /Users/anirudh/Library/Caches/pip/wheels/f6/f9/8a/e5153a07fee191fb3e7ed1ef181c3275d3ee3c094df585741d
#   Building wheel for scs (setup.py) ... done
#   Created wheel for scs: filename=scs-2.1.2-cp36-cp36m-macosx_10_9_x86_64.whl size=114942 sha256=e74b367fd76ebcbaa90db9d6a21de7dd00708483933097ca0874aded58991c76
#   Stored in directory: /Users/anirudh/Library/Caches/pip/wheels/50/02/c2/0708708e215645196adc1ea78c7dc776b173a37a86deb6a7e7
#   Building wheel for multiprocess (setup.py) ... done
#   Created wheel for multiprocess: filename=multiprocess-0.70.9-py3-none-any.whl size=100648 sha256=013ace7d1d7a40b817ed4827f9a2d8cc34d7ba7cbab30275d163018ce951b345
#   Stored in directory: /Users/anirudh/Library/Caches/pip/wheels/de/27/e1/ed8feb7bbcd35ac6a88ec23b50b4e1afad0a5bf06490981e58
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78530 sha256=669b57b06a9d6d2e2eed8036dc0eeb5328d9c0bffd8a6d43f43597c0b703be58
#   Stored in directory: /Users/anirudh/Library/Caches/pip/wheels/09/84/74/d2b4feb9ac9488bc83c475cb2cbe8e8b7d9cea8320d32f3787
# Successfully built alphalens cvxpy scs multiprocess dill
# Installing collected packages: numpy, python-dateutil, pytz, pandas, scipy, alphalens, colour, osqp, ecos, scs, dill, multiprocess, cvxpy, pyparsing, idna, urllib3, requests, tqdm, zipline, graphviz
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.16.4
#     Uninstalling numpy-1.16.4:
#       Successfully uninstalled numpy-1.16.4
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.0
#     Uninstalling python-dateutil-2.8.0:
#       Successfully uninstalled python-dateutil-2.8.0
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2019.2
#     Uninstalling pytz-2019.2:
#       Successfully uninstalled pytz-2019.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 0.22.0
#     Uninstalling pandas-0.22.0:
#       Successfully uninstalled pandas-0.22.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.3.1
#     Uninstalling scipy-1.3.1:
#       Successfully uninstalled scipy-1.3.1
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 2.4.2
#     Uninstalling pyparsing-2.4.2:
#       Successfully uninstalled pyparsing-2.4.2
#   Attempting uninstall: idna
#     Found existing installation: idna 2.8
#     Uninstalling idna-2.8:
#       Successfully uninstalled idna-2.8
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.2
#     Uninstalling urllib3-1.24.2:
#       Successfully uninstalled urllib3-1.24.2
#   Attempting uninstall: requests
#     Found existing installation: requests 2.22.0
#     Uninstalling requests-2.22.0:
#       Successfully uninstalled requests-2.22.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.32.1
#     Uninstalling tqdm-4.32.1:
#       Successfully uninstalled tqdm-4.32.1
#   Attempting uninstall: zipline
#     Found existing installation: zipline 1.3.0
#     Uninstalling zipline-1.3.0:
#       Successfully uninstalled zipline-1.3.0
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.13.2
#     Uninstalling graphviz-0.13.2:
#       Successfully uninstalled graphviz-0.13.2
# Successfully installed alphalens-0.3.2 colour-0.1.5 cvxpy-1.0.3 dill-0.3.1.1 ecos-2.0.7.post1 graphviz-0.9 idna-2.6 multiprocess-0.70.9 numpy-1.14.5 osqp-0.6.1 pandas-0.18.1 pyparsing-2.2.0 python-dateutil-2.6.1 pytz-2017.3 requests-2.18.4 scipy-1.0.0 scs-2.1.2 tqdm-4.19.5 urllib3-1.22 zipline-1.2.0
